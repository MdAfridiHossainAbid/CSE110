# %% [markdown]
# # **Lab01**

# %%
#Task 01
print("hello world")
# Out:
# hello world

# %%
#Task 02
print(54+56)
# Out:
# 110

# %%
#Task 03
season = "Summer"
year = "2023"
print(f'{season}\n{year}')
# Out:
# Summer
# 2023

# %%
#Task 04
for _ in range(2):
    user_input = input("Enter your name: ")
    print(f'Your name is {user_input}')
# Out:
# Enter your name: John
# Your name is John
# Enter your name: Albert
# Your name is Albert

# %%
#Task 05
for _ in range(2):
    m = int(input('Enter a number: '))
    n = int(input('Enter a number: '))
    formula = m ** n
    print(f'{m}^{n}: {formula}')
# Out:
# Enter a number: 2
# Enter a number: 3
# 2^3: 8
# Enter a number: 10
# Enter a number: 3
# 10^3: 1000

# %%
#Task 06
for _ in range(3):
    user_in = int(input('Enter the total weight of the shipment: '))
    remainder = user_in % 4
    max_load = user_in - remainder
    print(max_load)
# Out:
# Enter the total weight of the shipment: 9
# 8
# Enter the total weight of the shipment: 11
# 8
# Enter the total weight of the shipment: 23
# 20

# %%
#Task 07
for _ in range(3):
    a = int(input())
    b = int(input())
    c = int(input())
    d = float(input())
    formula110 = a**c + (b * a) - d/3
    print(int(formula110))
# Out:
# 2
# 6
# 8
# 1.3
# 267
# 9
# 100
# 1
# 3.7
# 907
# 88
# 22
# 1
# 3.3
# 2022

# %%
#Task 08
for _ in range(2):
    user_in = int(input("Total chocolates you have: "))
    remaining_chocolates = user_in % 3
    each_one_will_get = user_in // 3
    print(f'Each friend will receive {each_one_will_get} chocolates')
    print(f'The number of remaining chocolates is {remaining_chocolates}')
# Out:
# Total chocolates you have: 50
# Each friend will receive 16 chocolates
# The number of remaining chocolates is 2
# Total chocolates you have: 90
# Each friend will receive 30 chocolates
# The number of remaining chocolates is 0

# %%
#Task 09
for _ in range(3):
    m = input()
    n = input()
    result = n + m
    print(result)
# Out:
# 5
# 2
# 25
# Hello
# World
# WorldHello
# Python
# 3
# 3Python

# %%
#Task 10
for _ in range(2):
    a = int(input())
    b = float(input())
    c = int(input())
    sum = a + b
    print(f"The inputs: {a}, {b}, {c}")
    print(f"The result is {str(sum) + str(c)}")
# Out:
# 3
# 11.57
# 7
# The inputs: 3, 11.57, 7
# The result is 14.577
# 33
# 1.9
# 753
# The inputs: 33, 1.9, 753
# The result is 34.9753

# %%
#Task 11
for _ in range(4):
    user_input = int(input())
    if user_input % 2 == 0:
        print("True")
    else:
        print("False")
# Out:
# 7
# False
# 0
# True
# -11
# False
# -26
# True
